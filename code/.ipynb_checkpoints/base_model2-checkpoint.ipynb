# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn import preprocessing, model_selection, metrics
import lightgbm as lgb

# %%
train_df = pd.read_csv("../data/train.csv", parse_dates=["activation_date"]).sample(10000)
test_df = pd.read_csv("../data/test.csv", parse_dates=["activation_date"]).sample(10000)

train_df = train_df.reset_index().drop('index', axis=1)
test_df = test_df.reset_index().drop('index', axis=1)

print("Train file rows and columns are: ", train_df.shape)
print("Test file rows and columns are: ", test_df.shape)
# Out:
# Train file rows and columns are:  (10000, 18)
# Test file rows and columns are:  (10000, 17)

# %%
# targt and ID 
train_y = train_df["deal_probability"].values
test_id = test_df["item_id"].values

# New variable on weekday
train_df["activation_weekday"] = train_df["activation_date"].dt.weekday
test_df["activation_weekday"] = test_df["activation_date"].dt.weekday

# Label encode the categorical variables
categoricals = ["region", "city", "parent_category_name", "category_name", "user_type", "param_1", "param_2", "param_3"]

for col in categoricals:
    lbl = preprocessing.LabelEncoder()
    lbl.fit(list(train_df[col].values.astype('str')) + list(test_df[col].values.astype('str')))
    train_df[col] = lbl.transform(list(train_df[col].values.astype('str')))
    test_df[col] = lbl.transform(list(test_df[col].values.astype('str')))

cols_to_drop = ["item_id", "user_id", "title", "description", "activation_date", "image"]
train_X = train_df.drop(cols_to_drop + ["deal_probability"], axis=1)
test_X = test_df.drop(cols_to_drop, axis=1)

# %%
train_X.head()
# Out:
#    region  city  parent_category_name  category_name  param_1  param_2  \
# 0      14    73                     5             39      113        1
# 1      24    10                     3             20      246      106
# 2      18   359                     4              4      100       15
# 3      21   255                     4              4      108      164
# 4       3   626                     4             25      275      106
#
#    param_3      price  item_seq_number  user_type  image_top_1  \
# 0       50  1500000.0               47          0       2219.0
# 1       44     6000.0                8          1       2126.0
# 2       45      600.0               48          1        557.0
# 3      160      300.0                4          1         42.0
# 4       44      350.0               67          1       1660.0
#
#    activation_weekday
# 0                   2
# 1                   0
# 2                   3
# 3                   0
# 4                   4

# %%
def run_lgb(train_X, train_y, val_X, val_y, test_X):
    params = {
        "objective" : "regression",
        "metric" : "rmse",
        "num_leaves" : 30,
        "learning_rate" : 0.1,
        "bagging_fraction" : 0.7,
        "feature_fraction" : 0.7,
        "bagging_frequency" : 5,
        "bagging_seed" : 2018,
        "verbosity" : -1
    }
    
    lgtrain = lgb.Dataset(train_X, label=train_y)
    lgval = lgb.Dataset(val_X, label=val_y)
    evals_result = {}
    model = lgb.train(params, lgtrain, 1000, valid_sets=[lgval], early_stopping_rounds=100, verbose_eval=20, evals_result=evals_result)
    
    pred_test_y = model.predict(test_X, num_iteration=model.best_iteration)
    return pred_test_y, model, evals_result

# %%
# Splitting the data for model training#
dev_X = train_X.iloc[:-5000,:]
val_X = train_X.iloc[-5000:,:]
dev_y = train_y[:-5000]
val_y = train_y[-5000:]
print(dev_X.shape, val_X.shape, test_X.shape)

# Training the model 
pred_test, model, evals_result = run_lgb(dev_X, dev_y, val_X, val_y, test_X)

# Making a submission file
pred_test[pred_test>1] = 1
pred_test[pred_test<0] = 0
sub_df = pd.DataFrame({"item_id":test_id})
sub_df["deal_probability"] = pred_test

sub_df
#sub_df.to_csv("baseline_lgb.csv", index=False)
# Out:
# (5000, 12) (5000, 12) (10000, 12)
# Training until validation scores don't improve for 100 rounds.
# [20]	valid_0's rmse: 0.236022
# [40]	valid_0's rmse: 0.236197
# [60]	valid_0's rmse: 0.236786
# [80]	valid_0's rmse: 0.237697
# [100]	valid_0's rmse: 0.238665
# [120]	valid_0's rmse: 0.23945
# Early stopping, best iteration is:
# [24]	valid_0's rmse: 0.235784
#            item_id  deal_probability
# 0     f6b6571c87c2          0.084448
# 1     9c0cf4d8e47a          0.056217
# 2     48ae1d7128fb          0.253789
# 3     7fcd52a968fc          0.138565
# 4     dbc17137eb3a          0.060931
# 5     ee164e99ceb4          0.188860
# 6     ac7e4933eccf          0.060761
# 7     b12ad96d7592          0.111099
# 8     1c27bb86b6e6          0.055940
# 9     bb80ab1a3dcb          0.431752
# 10    48107e28b116          0.136728
# 11    a9e32a2fdc90          0.203380
# 12    52d0a026b486          0.184050
# 13    1a79f0435c53          0.203778
# 14    abf0570b1eda          0.178860
# 15    9c75cf430dca          0.079615
# 16    ba18a9f031aa          0.129380
# 17    f6be0c2dd5af          0.063232
# 18    29f0b4a52c80          0.088858
# 19    db6691d25b3b          0.056635
# 20    650625d115bf          0.080054
# 21    12679c20e227          0.059813
# 22    5421625fc686          0.202659
# 23    f98106938a63          0.215674
# 24    86e00696de9a          0.063433
# 25    d25ce0edcaa7          0.161781
# 26    691b35aaa712          0.051010
# 27    9653e8aa508f          0.060619
# 28    f853c6dbee63          0.132862
# 29    2d3df5ee051d          0.116223
# ...            ...               ...
# 9970  fcaf2dbe7e18          0.070419
# 9971  53f14bdc837d          0.245462
# 9972  411325705529          0.048492
# 9973  e444c58cbec0          0.052809
# 9974  7dd5be791c61          0.218234
# 9975  b6037762dd1c          0.180824
# 9976  1f6370a2fdbc          0.125661
# 9977  5e22fccc0f02          0.069306
# 9978  19520b541fd4          0.152261
# 9979  484b05feb3ae          0.234043
# 9980  6f05b69c9530          0.180122
# 9981  7a852502650e          0.054664
# 9982  df520ef21133          0.060798
# 9983  026a139cc3ed          0.241589
# 9984  bfff235a4744          0.132736
# 9985  9f9473376df0          0.382144
# 9986  696531958e02          0.404352
# 9987  ab0f7d83e8d8          0.122939
# 9988  a9431e152c3b          0.077607
# 9989  6874e5982898          0.258977
# 9990  7b0f761df0f9          0.062602
# 9991  a1ae8de932eb          0.158027
# 9992  3878bd79ba3d          0.066894
# 9993  ce83c466f136          0.063681
# 9994  e00187a7772d          0.088627
# 9995  eedc6656db77          0.107949
# 9996  df47ca96c433          0.122985
# 9997  a1895f470c78          0.191894
# 9998  bec80da06311          0.093314
# 9999  00c544056de0          0.210972
#
# [10000 rows x 2 columns]

# %%
fig, ax = plt.subplots(figsize=(12,18))
lgb.plot_importance(model, max_num_features=50, height=0.8, ax=ax)
ax.grid(False)
plt.title("LightGBM - Feature Importance", fontsize=15)
plt.show()
